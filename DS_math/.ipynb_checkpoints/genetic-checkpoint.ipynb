# %%
#выражение, которое пытаемся максимизировать
#Y = sin(w1x1 + w2x2 + w3x3 + w4x4 + w5x5 + w6x6)
#(x1,x2,x3,x4,x5,x6)=(4,-2 ,7, 5,-11, 1) - такие иксы
# пытаемся подобрать w такие, чтобы Y был максимаьным
#
#
#

# %%
# входные данные
equation_inputs = [4, -2, 7, 5, -11, 1]
# количество весов
num_weights = len(equation_inputs)

# %%
import numpy as np

sol_per_pop = 8  # определяем, сколько решений будет у первой "популяции"

pop_size = (sol_per_pop, num_weights) # таков размер первой популяции.

#создаем первую популяцию случайно.
new_population = np.random.uniform(low=-4.0, high=4.0, size=pop_size)
for elem in new_population:
    print(elem)
# Out:
# [-1.31035402  3.87374982  0.67894627 -1.17448426  0.65041838  2.87175321]
# [ 3.84626685  3.25800048 -1.44102736 -3.03997085 -3.42789177  3.98601981]
# [-0.66715095  3.63878798 -0.65151253 -3.56797186  1.65531303  3.43828436]
# [-1.10040407  3.80619101  2.94785557 -1.34869651 -0.80607756 -3.0779558 ]
# [-0.42657963 -3.33044679  2.93475883  0.02661925  1.39219214  3.57196829]
# [-2.16489227  3.46400099  2.67158898  1.08202675 -2.85235559 -1.36143345]
# [-3.93430296  2.75256084  2.67259736  2.66812699  3.35855732  0.89552215]
# [-3.33146182 -3.40523392 -1.18472343  1.34898767 -1.2957139  -3.57054738]

# %%
# функция для посчета, насколько ответ подходящий (просто считаем У)
def cal_pop_fitness(equation_inputs, pop):
    fitness = sin(np.sum(pop*equation_inputs, axis=1))
    return fitness


def select_mating_pool(pop, fitness, num_parents):
    #выбираем наилучших "родителей" в популяции
    parents = np.empty((num_parents, pop.shape[1]))
    for parent_num in range(num_parents):
        max_fitness_idx = np.where(fitness == numpy.max(fitness))
        max_fitness_idx = max_fitness_idx[0][0]
        parents[parent_num, :] = pop[max_fitness_idx, :]
        fitness[max_fitness_idx] = -99999999999
    return parents


def crossover(parents, offspring_size):
    offspring = np.empty(offspring_size)
    # Точка, в которой появляется кроссовер 
    crossover_point = np.uint8(offspring_size[1]/2)
    for k in range(offspring_size[0]):
     #индекс перого родителя
     parent1_idx = k%parents.shape[0]
     #индекс второго родителя
     parent2_idx = (k+1)%parents.shape[0]
     #половину "генов" берем от одного родителя
     offspring[k, 0:crossover_point] = parents[parent1_idx, 0:crossover_point]
     #половину "генов" берем от второго родителя
     offspring[k, crossover_point:] = parents[parent2_idx, crossover_point:]
    return offspring


def mutation(offspring_crossover):
    # Мутация изменят "гены" случайно
    for idx in range(offspring_crossover.shape[0]):
        # добавим рандомное число в ген
        random_value = np.random.uniform(-1.0, 1.0, 1)
        offspring_crossover[idx, 4] = offspring_crossover[idx, 4] + random_value
    return offspring_crossover

# %%
#количество повторений
num_generations = 5

#количество "родителей", которые участвуют в формировании новых ответов
num_parents_mating = 4

for generation in range(num_generations):
    # Подсчиываем "подходящесть"
    fitness = cal_pop_fitness(equation_inputs, new_population)
    # выбираем лучших родителей.
    parents = select_mating_pool(new_population, fitness, 
                                   num_parents_mating)

    # генерируем новый ответ
    offspring_crossover = crossover(parents,
                                    offspring_size=(pop_size[0]-parents.shape[0], num_weights))

    # добавляем "мутацию" (случайное смещение).
    offspring_mutation = mutation(offspring_crossover)
    new_population[0:parents.shape[0], :] = parents
    new_population[parents.shape[0]:, :] = offspring_mutation
    print("Generation ", generation)
    print("Fitness")
    print(fitness)
    print('Parents')
    print(parents)
    print('Mutation')
    print(offspring_mutation)
    print("Best fitness ", np.max(fitness))
    print('-------------------------------------------------------------')
# Out:
# Generation  0
# Fitness
# [-3.71368674e+01 -1.00000000e+11 -6.44347127e+01 -1.00000000e+11
#  -1.67430373e+01 -1.00000000e+11 -3.97006924e+01 -1.00000000e+11]
# Parents
# [[-2.16489227  3.46400099  2.67158898  1.08202675 -2.85235559 -1.36143345]
#  [-3.33146182 -3.40523392 -1.18472343  1.34898767 -1.2957139  -3.57054738]
#  [-1.10040407  3.80619101  2.94785557 -1.34869651 -0.80607756 -3.0779558 ]
#  [ 3.84626685  3.25800048 -1.44102736 -3.03997085 -3.42789177  3.98601981]]
# Mutation
# [[-2.16489227  3.46400099  2.67158898  1.34898767 -1.01350595 -3.57054738]
#  [-3.33146182 -3.40523392 -1.18472343 -1.34869651 -1.71698849 -3.0779558 ]
#  [-1.10040407  3.80619101  2.94785557 -3.03997085 -2.8045765   3.98601981]
#  [ 3.84626685  3.25800048 -1.44102736  1.08202675 -3.25471925 -1.36143345]]
# Best fitness  -16.74303732982395
# -------------------------------------------------------------
# Generation  1
# Fitness
# [-1.00000000e+11 -1.00000000e+11  1.48932591e+01  7.59813285e+00
#  -1.00000000e+11  1.59478717e+01 -4.78030972e+00 -1.00000000e+11]
# Parents
# [[ 3.84626685  3.25800048 -1.44102736  1.08202675 -3.25471925 -1.36143345]
#  [-2.16489227  3.46400099  2.67158898  1.08202675 -2.85235559 -1.36143345]
#  [-2.16489227  3.46400099  2.67158898  1.34898767 -1.01350595 -3.57054738]
#  [-3.33146182 -3.40523392 -1.18472343  1.34898767 -1.2957139  -3.57054738]]
# Mutation
# [[ 3.84626685  3.25800048 -1.44102736  1.08202675 -2.88871578 -1.36143345]
#  [-2.16489227  3.46400099  2.67158898  1.34898767 -0.13273848 -3.57054738]
#  [-2.16489227  3.46400099  2.67158898  1.34898767 -0.92917426 -3.57054738]
#  [-3.33146182 -3.40523392 -1.18472343  1.08202675 -2.93588757 -1.36143345]]
# Best fitness  15.947871659843518
# -------------------------------------------------------------
# Generation  2
# Fitness
# [-1.00000000e+11 -1.00000000e+11  2.84380668e+01  2.71174525e+01
