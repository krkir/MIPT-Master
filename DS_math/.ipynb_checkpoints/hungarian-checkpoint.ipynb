# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np


img = cv2.imread('people.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img)
print(img.shape)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_8727/3973931106.py in <module>
#       6 img = cv2.imread('people.jpg')
#       7 #img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# ----> 8 plt.imshow(img)
#       9 print(img.shape)
#
# ~/.local/lib/python3.9/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2901         filternorm=True, filterrad=4.0, resample=None, url=None,
#    2902         data=None, **kwargs):
# -> 2903     __ret = gca().imshow(
#    2904         X, cmap=cmap, norm=norm, aspect=aspect,
#    2905         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# ~/.local/lib/python3.9/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/.local/lib/python3.9/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, **kwargs)
#    5607                               resample=resample, **kwargs)
#    5608
# -> 5609         im.set_data(X)
#    5610         im.set_alpha(alpha)
#    5611         if im.get_clip_path() is None:
#
# ~/.local/lib/python3.9/site-packages/matplotlib/image.py in set_data(self, A)
#     698         if (self._A.dtype != np.uint8 and
#     699                 not np.can_cast(self._A.dtype, float, "same_kind")):
# --> 700             raise TypeError("Image data of dtype {} cannot be converted to "
#     701                             "float".format(self._A.dtype))
#     702
#
# TypeError: Image data of dtype object cannot be converted to float

# %%
boxes1 = [
    [950, 1070, 300, 680], #x1, x2, y1, y2
    [800, 910, 300, 680],
    [840, 920, 170, 400],
    [720, 820, 150, 400],
]

boxes2 = [
    [955, 1065, 304, 680],
    [803, 913, 310, 680],
    [841, 920, 180, 400],
    [600, 670, 380, 700],
]

def draw_box(box, img):
    color = [0, 0, 0]
    img_data = cv2.rectangle(img, (int(box[0]), int(box[2])), (int(box[1]), int(box[3])), color, 2)

for box in boxes2:
    draw_box(box, img)
    
plt.imshow(img)

# %%
#функция для расчета похожести (или непохожести) двух коробок
def calculate_similarity(box1, box2):
    metric = 1
    return metric

# %%
#функция для генерации матрицы стоимости
def build_cost_matrix(boxes1, boxes2):
    cost = []
    return cost

# %%
from scipy.optimize import linear_sum_assignment

cols, rows = linear_sum_assignment()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-b3b5702be83d> in <module>()
#       1 from scipy.optimize import linear_sum_assignment
#       2
# ----> 3 cols, rows = linear_sum_assignment()
#       4
#       5 #что надо проверить:
#
# TypeError: linear_sum_assignment() missing 1 required positional argument: 'cost_matrix'
